# %%
import numpy as np
import pandas as pd

# %%
pd.DataFrame(np.array([1])).sample(10, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12980/3568562825.py in <module>
# ----> 1 pd.DataFrame(np.array([1])).sample(10, random_state=1)
#
# ~\anaconda3\envs\gitlaw\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5363             )
#    5364
# -> 5365         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5366         result = self.take(locs, axis=axis)
#    5367         if ignore_index:
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
9925/(9925+1676)
# Out:
# 0.8555296957158866

# %%
for k in []:
    print(k)
    print(type(k))

# %%
import os, psutil
process = psutil.Process(os.getpid())
print(process.memory_info().rss)  # in bytes
# Out:
# 51789824

# %%
print("asdgjn", psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
# Out:
# asdgjn 49.50390625

# %%
import numpy as np

# %%
import sys 
from sys import getsizeof

# %%
class t():
    
    def __init__(self):
        self.z = 1
        
    def f(self):
        print("asdgjn", psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
        x = np.linspace(1, 2, 12343658)
        y = x.copy()
        print("SPEICHER", psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
        #print(dir())
        #print(globals())
        #for n in dir():
        #    if n[:2] == "_i" and n[:2] != "__":
        #        del globals()[n]
        #print("asdgjn", psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
        #print("NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN", dir())
        #print("GGGLLLOOOBBBAAALLLSSS", globals())
        print("SPEICHERRR", psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
        del x
        del y
        print("asdgjn", psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)

# %%
t().f()
# Out:
# asdgjn 60.203125
# SPEICHER 248.66796875
# SPEICHERRR 248.66796875
# asdgjn 60.31640625

# %%
x = np.linspace(1, 2, 1258)

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import os, psutil\nprocess = psutil.Process(os.getpid())\nprint(process.memory_info().rss)  # in bytes ',
#   'print("asdgjn", psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)',
#   'import numpy as np',
#   'import sys \nfrom sys import getsizeof',
#   'class t():\n    \n    def __init__(self):\n        self.z = 1\n        \n    def f(self):\n\n        x = np.linspace(1, 2, 1258)\n        y = x.copy()\n\n        print(dir())\n        print(globals())\n        \n        print(dir)',
#   't().f()',
#   'globals()'],
#  '_oh': {},
#  '_dh': ['C:\\Users\\larsw'],
#  'In': ['',
#   'import os, psutil\nprocess = psutil.Process(os.getpid())\nprint(process.memory_info().rss)  # in bytes ',
# ...

# %%
t().f()
# Out:
# ['self', 'x', 'y']
# ...

# %%
import sys

# %%
this = sys.modules[__name__]
for n in dir():
    if n[0]!="_": delattr(this, n)

# %%
x = 1
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit',
#  'x']

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
x = 1

# %%
for element in dir():
    if element[0:2] != "__" and element[0] != "_":
        del globals()[element]

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'globals()',
#   'for element in dir():\n    if element[0:2] != "__" and element[0] != "_":\n        del globals()[element]',
#   'globals()',
#   'globals()',
#   'globals()'],
#  '_oh': {1: {...}, 3: {...}, 4: {...}},
#  '_dh': ['C:\\Users\\larsw'],
#  '_': {...},
#  '__': {...},
#  '___': {...},
#  '_i': 'globals()',
#  '_ii': 'globals()',
#  '_iii': 'for element in dir():\n    if element[0:2] != "__" and element[0] != "_":\n        del globals()[element]',
#  '_i1': 'globals()',
#  '_1': {...},
#  '_i2': 'for element in dir():\n    if element[0:2] != "__" and element[0] != "_":\n        del globals()[element]',
#  'element': 'quit',
#  '_i3': 'globals()',
#  '_3': {...},
# ...

# %%
this = sys.modules[__name__]
this
# Out:
# <module '__main__'>

# %%
locals().items()
# Out:
# dict_items([('__name__', '__main__'), ('__doc__', 'Automatically created module for IPython interactive environment'), ('__package__', None), ('__loader__', None), ('__spec__', None), ('__builtin__', <module 'builtins' (built-in)>), ('__builtins__', <module 'builtins' (built-in)>), ('_ih', ['', 'import os, psutil\nprocess = psutil.Process(os.getpid())\nprint(process.memory_info().rss)  # in bytes ', 'print("asdgjn", psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)', 'import numpy as np', 'import sys \nfrom sys import getsizeof', 'class t():\n    def f():\n        print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)\n        x = np.linspace(1, 2, 1258)\n        y = x.copy()\n        print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)\n        print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)\n        for k in locals().items():\n            print(k[1], type(k[1]))\n\n        import sys\n        this = sys.modules[__name__]\n        for 
# ...

# %%
sys.modules[__name__]
# Out:
# <module '__main__'>

# %%
L = [1, 2, 3, 4, 5]

# %%
delattr?

# %%
print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
# Out:
# 1012.5078125

# %%
x = np.linspace(1, 2, 124823958)

# %%
print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
# Out:
# 1012.515625

# %%
y = np.array([1, 2])

# %%
print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
# Out:
# 1012.5390625

# %%
z = np.arange(1, 10000)

# %%
print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
# Out:
# 1012.609375

# %%
R = []
for k in range(100000):
    R.append(np.random.randint(1, 4))

# %%
R
# Out:
# [1,
#  3,
#  1,
#  2,
#  3,
#  2,
#  3,
#  3,
#  3,
#  2,
#  1,
#  1,
#  3,
#  1,
#  2,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  2,
#  3,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  1,
#  3,
#  3,
#  1,
#  1,
#  1,
#  2,
#  1,
#  2,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  2,
#  3,
#  3,
#  1,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  1,
#  3,
#  3,
#  2,
#  3,
#  3,
#  1,
#  2,
#  2,
#  3,
#  2,
#  3,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  1,
#  3,
#  2,
#  1,
#  2,
#  3,
#  1,
#  3,
#  1,
#  2,
#  1,
#  3,
#  2,
#  1,
#  2,
#  3,
#  3,
#  3,
#  1,
#  3,
#  2,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  3,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  3,
#  3,
#  2,
#  2,
#  1,
#  1,
#  1,
#  2,
#  3,
#  3,
#  2,
#  3,
#  3,
#  1,
#  3,
#  2,
#  1,
#  1,
#  2,
#  2,
#  2,
#  1,
#  2,
#  3,
#  2,
#  3,
#  2,
#  1,
#  2,
#  3,
#  3,
# ...

# %%
print(psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2)
# Out:
# 1013.5625
